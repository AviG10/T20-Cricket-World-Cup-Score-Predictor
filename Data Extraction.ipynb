# %%
import numpy as np #used for working with arrays
import pandas as pd #used for analyzing,cleaning,exploring and manupulating data
from yaml import safe_load #load subset of the yaml safely
import os #provides functions for interacting with OS
from tqdm import tqdm #used for creating progress bar

# %%
#extracting the filenames using os module
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data/1173055.yaml',
#  'data/951375.yaml',
#  'data/1188621.yaml',
#  'data/540173.yaml',
#  'data/1034829.yaml']

# %%
#creating dataframe from yaml files
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f)) #json_normalize convert 
        #each record in the list into a row of tabular form
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#   0%|          | 0/1432 [00:00<?, ?it/s]/var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 1/1432 [00:00<03:27,  6.89it/s]/var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 2/1432 [00:00<02:51,  8.35it/s]/var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Namibia', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Canada', 'deliverie...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
#
#    meta.created  meta.revision     info.city    info.dates info.gender  \
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...      Canberra
# 0   [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...      St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Chattogram
# 0   [{'1st innings': {'team': 'Namibia', 'deliveri...      Arbroath
# 0   [{'1st innings': {'team': 'Canada', 'deliverie...      Hamilton
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...  Kuala Lumpur
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/2142223783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...      St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...    Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...     Abu Dhabi
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/3157072726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...      St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...    Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...     Abu Dhabi
# ...

# %%
import pickle #used to save python object on the disk
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
# extracting the ball by ball data
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'non_striker': 'E Lewis',
#    'bowler': 'Washington Sundar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Campbell'}},
#  {0.2: {'non_striker': 'E Lewis',
#    'bowler': 'Washington Sundar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Campbell',
#    'wicket': {'player_out': 'JD Campbell',
#     'fielders': ['KH Pandya'],
#     'kind': 'caught'}}},
#  {0.3: {'non_striker': 'E Lewis',
#    'bowler': 'Washington Sundar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'N Pooran'}},
#  {0.4: {'non_striker': 'E Lewis',
#    'bowler': 'Washington Sundar',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'N Pooran'}},
#  {0.5: {'non_striker': 'N Pooran',
#    'bowler': 'Washington Sundar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'E Lewis'}},
#  {0.6: {'non_striker': 'N Pooran',
#    'bowler': 'Washington Sundar',
# ...

# %%
#batting_team,bowling_team,current_score,wickets_left,current_run_rate,city,balls_left,last_five

count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():  #iterrows used to iterate over pandas data frame rows in (index,series) pair
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_1088/3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
delivery_df
# Out:
#      match_id                    teams batting_team  ball  \
# 0           2     [India, West Indies]  West Indies   0.1
# 1           2     [India, West Indies]  West Indies   0.2
# 2           2     [India, West Indies]  West Indies   0.3
# 3           2     [India, West Indies]  West Indies   0.4
# 4           2     [India, West Indies]  West Indies   0.5
# ..        ...                      ...          ...   ...
# 118       964  [Pakistan, New Zealand]     Pakistan  19.2
# 119       964  [Pakistan, New Zealand]     Pakistan  19.3
# 120       964  [Pakistan, New Zealand]     Pakistan  19.4
# 121       964  [Pakistan, New Zealand]     Pakistan  19.5
# 122       964  [Pakistan, New Zealand]     Pakistan  19.6
#
#                  batsman             bowler  runs player_dismissed  \
# 0            JD Campbell  Washington Sundar     0                0
# 1            JD Campbell  Washington Sundar     0      JD Campbell
# ...

# %%
#extract bowling team
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                    teams batting_team  ball  \
# 0           2     [India, West Indies]  West Indies   0.1
# 1           2     [India, West Indies]  West Indies   0.2
# 2           2     [India, West Indies]  West Indies   0.3
# 3           2     [India, West Indies]  West Indies   0.4
# 4           2     [India, West Indies]  West Indies   0.5
# ..        ...                      ...          ...   ...
# 118       964  [Pakistan, New Zealand]     Pakistan  19.2
# 119       964  [Pakistan, New Zealand]     Pakistan  19.3
# 120       964  [Pakistan, New Zealand]     Pakistan  19.4
# 121       964  [Pakistan, New Zealand]     Pakistan  19.5
# 122       964  [Pakistan, New Zealand]     Pakistan  19.6
#
#                  batsman             bowler  runs player_dismissed  \
# 0            JD Campbell  Washington Sundar     0                0
# 1            JD Campbell  Washington Sundar     0      JD Campbell
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['West Indies', 'India', 'England', 'South Africa', 'Netherlands',
#        'New Zealand', 'Afghanistan', 'Pakistan', 'Kenya', 'Australia',
#        'Malaysia', 'Ireland', 'Zimbabwe', 'Nigeria', 'Singapore', 'Nepal',
#        'Bangladesh', 'Vanuatu', 'Hong Kong', 'United Arab Emirates',
#        'Thailand', 'Canada', 'Sri Lanka', 'Papua New Guinea', 'Spain',
#        'Scotland', 'Belgium', 'Oman', 'Kuwait', 'Jersey', 'Gibraltar',
#        'Denmark', 'Cayman Islands', 'United States of America',
#        'Philippines', 'Ghana', 'Guernsey', 'Namibia', 'Bermuda', 'Qatar',
#        'Germany', 'Botswana', 'Italy', 'Romania', 'Norway', 'Isle of Man',
#        'Uganda', 'Maldives', 'Bulgaria', 'Iran', 'Bhutan', 'Portugal'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball              batsman             bowler  \
# 0           2  West Indies   0.1          JD Campbell  Washington Sundar
# 1           2  West Indies   0.2          JD Campbell  Washington Sundar
# 2           2  West Indies   0.3             N Pooran  Washington Sundar
# 3           2  West Indies   0.4             N Pooran  Washington Sundar
# 4           2  West Indies   0.5              E Lewis  Washington Sundar
# ..        ...          ...   ...                  ...                ...
# 118       964     Pakistan  19.2  Shaheen Shah Afridi         BM Tickner
# 119       964     Pakistan  19.3        Faheem Ashraf         BM Tickner
# 120       964     Pakistan  19.4  Shaheen Shah Afridi         BM Tickner
# 121       964     Pakistan  19.5  Shaheen Shah Afridi         BM Tickner
# 122       964     Pakistan  19.6           Haris Rauf         BM Tickner
#
#      runs player_dismissed        city  \
# 0       0                0  Lauderhill
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city                                              venue
# 0    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
