# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city                                              venue
# 0    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8545
# venue                  0
# dtype: int64

# %%
#venue at which city is missing
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2966
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
#replace city by first word of venue
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city
# 0    Lauderhill
# 1    Lauderhill
# 2    Lauderhill
# 3    Lauderhill
# 4    Lauderhill
# ..          ...
# ...

# %%
#we will consider those cities where minimum 5 matches happens that is minimum 600 balls bowled
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city
# 0    Lauderhill
# 1    Lauderhill
# 2    Lauderhill
# 3    Lauderhill
# 4    Lauderhill
# ..          ...
# ...

# %%
#extracting current score by cummulative sum
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/4140170271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city  current_score
# 0    Lauderhill              0
# 1    Lauderhill              0
# 2    Lauderhill              0
# ...

# %%
#split ball coloumn by dot(.) where left part will be over and right part will be balls
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/3048514499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/3048514499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/4058181551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# ...

# %%
# if balls left is less than zero then i am keeping it as zero
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1139489691.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1139489691.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
#if player dismissed is zero then keep it as zero otherwise replace it with 1 and 
# then find cummulative sum and subtract from 10 to get wickets left
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1786089940.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1786089940.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ...

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2  West Indies        India   0.1     0                 0
# 1           2  West Indies        India   0.2     0                 1
# 2           2  West Indies        India   0.3     0                 1
# 3           2  West Indies        India   0.4     1                 1
# 4           2  West Indies        India   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 118       964     Pakistan  New Zealand  19.2     1                 8
# 119       964     Pakistan  New Zealand  19.3     0                 9
# 120       964     Pakistan  New Zealand  19.4     2                 9
# 121       964     Pakistan  New Zealand  19.5     1                 9
# 122       964     Pakistan  New Zealand  19.6     1                 9
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
#creating current run rate coloumn
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1430540559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2  West Indies        India   0.1     0                 0
# 1           2  West Indies        India   0.2     0                 1
# 2           2  West Indies        India   0.3     0                 1
# 3           2  West Indies        India   0.4     1                 1
# 4           2  West Indies        India   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 118       964     Pakistan  New Zealand  19.2     1                 8
# 119       964     Pakistan  New Zealand  19.3     0                 9
# 120       964     Pakistan  New Zealand  19.4     2                 9
# 121       964     Pakistan  New Zealand  19.5     1                 9
# 122       964     Pakistan  New Zealand  19.6     1                 9
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# calculating last five over or 30 balls sum . for firt 30 balls there will be nolast five over sum
#so it will be Nan for first 30 balls
groups = df.groupby('match_id') #group data on the basis of match id

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/4107368005.py:8: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# /var/folders/g2/k_kf5sls05952rxwh6x6dd_c0000gn/T/ipykernel_4521/1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
#df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','']]

# %%
# calculate final score in every match
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
#drop all missing values
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
#shuffling the values so that no baised developed
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 47195       England     Australia     Cape Town             75          53
# 46489     Australia         India        Sydney            156          13
# 33308    Bangladesh         India       Colombo            119          15
# 16356         India    Bangladesh       Colombo            126          24
# 23127     Australia  South Africa  Johannesburg             82          41
# ...             ...           ...           ...            ...         ...
# 35635      Pakistan    Bangladesh        Mirpur            128          31
# 35491   New Zealand  South Africa        Durban             97          52
# 13122  South Africa     Australia     Cape Town             57          91
# 8799      Sri Lanka         India    Chandigarh             96          67
# 24819         India      Pakistan     Bangalore            117          21
#
#        wickets_left        crr  last_five  runs_x
# ...

# %%
X = final_df.drop(columns=['runs_x']) #extracting x
y = final_df['runs_x'] #extracting y 
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 40951   New Zealand     Pakistan    Barbados             62          58
# 31640   West Indies    Australia      Sydney             59          60
# 35996     Australia        India   Melbourne             69          47
# 18796         India    Australia      Mirpur             95          33
# 38077    Bangladesh  West Indies  Lauderhill             67          59
# ...             ...          ...         ...            ...         ...
# 37480   New Zealand    Australia    Auckland            114          34
# 30158  South Africa  New Zealand    Auckland             91          65
# 22854   New Zealand  West Indies    Auckland             75          58
# 23505       England  Afghanistan       Delhi             85          34
# 10354     Sri Lanka  New Zealand  Nottingham            141          10
#
#        wickets_left       crr  last_five
# 40951             6  6.000000       22.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
# from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
#As 'batting_team','bowling_team','city'these column is in string so we have to oneHotEncode it that is
# encode categorical features as one-hot numeric array and passthrough rest columns

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
#creating pipeline
pipe = Pipeline(steps=[
    ('step1',trf), #oneHotEncode first
    ('step2',StandardScaler()), #Scaling the data
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1)) #run XGboost Regressor next
])

# n_estimators = no. of trees
# learning_rate = shrinkage we do at every step we are making
# max_depth = maximum depth of the tree i.e the longest path between root and leaf node
#  random_state = provides seed value to function's internal random number generator

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# ----------------------r2_score---------------------
#r2_score is the amount of the variation in the output dependent attribute which is predictable
# from the input independent variable(s).
#R2= 1- SSres / SStot ,SSres is the sum of squares of the residual errors and 
# SStot is the total sum of the errors.
#It is used to check how well-observed results are reproduced by the model, 
# depending on the ratio of total deviation of results described by the model.


# ----------------------mean absolute error---------------------
#Mean Absolute Error calculates the average difference between the calculated values and actual values. 
#It calculates errors between actual values and values predicted by the model. 
#Mean Absolute Error = (1/n) * Σ|yi – xi|
# Σ: Greek symbol for summation
# yi: Actual value for the ith observation
# xi: Calculated value for the ith observation
# n: Total number of observations
# Out:
# 0.9885562924154727
# 1.6382103094269023

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.6.0'
